# %% [markdown]
# Connected to geneformer (Python 3.10.3)

# %%
from datasets import load_from_disk

dataset = load_from_disk("./human_dcm_hcm_nf.dataset")

# %%
from datasets import load_from_disk

dataset = load_from_disk("./human_dcm_hcm_nf.dataset")

# %%
dataset
# Out:
# Dataset({
#     features: ['input_ids', 'length', 'cell_type', 'individual', 'age', 'sex', 'disease', 'lvef'],
#     num_rows: 579159
# })

# %%
from datasets import load_from_disk
from utils import filter_by_dict

# select three classes
filter_data_dict={"cell_type":["Cardiomyocyte1","Cardiomyocyte2","Cardiomyocyte3"]}

dataset = load_from_disk("./human_dcm_hcm_nf.dataset")

nproc = 8 # for processing speed

dataset = filter_by_dict(dataset,filter_data_dict,nproc)
# Out:
# Filter (num_proc=8):   0%|          | 0/579159 [00:00<?, ? examples/s]

# %%
dataset['cell_type']
# Out:
# ['Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
#  'Cardiomyocyte1',
# ...

# %%
len(dataset['cell_type'])
# Out:
# 144962

# %%
set(dataset['cell_type'])
# Out:
# {'Cardiomyocyte1', 'Cardiomyocyte2', 'Cardiomyocyte3'}

# %%
import numpy as np

# %%
np.pad([1,2,3],(0,5),mode="constant",constant_values=-1)
# Out:
# array([ 1,  2,  3, -1, -1, -1, -1, -1])

# %%
dataset['length']
# Out:
# [2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
#  2048,
# ...

# %%
max(dataset['length'])
# Out:
# 2048

# %%
dataset["state_key"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 dataset["state_key"]
#
# File c:\Users\xfang\anaconda3\envs\geneformer\lib\site-packages\datasets\arrow_dataset.py:2810, in Dataset.__getitem__(self, key)
#    2808 def __getitem__(self, key):  # noqa: F811
#    2809     """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2810     return self._getitem(key)
#
# File c:\Users\xfang\anaconda3\envs\geneformer\lib\site-packages\datasets\arrow_dataset.py:2794, in Dataset._getitem(self, key, **kwargs)
#    2792 format_kwargs = format_kwargs if format_kwargs is not None else {}
#    2793 formatter = get_formatter(format_type, features=self._info.features, **format_kwargs)
# -> 2794 pa_subtable = query_table(self._data, key, indices=self._indices)
#    2795 formatted_output = format_table(
# ...

# %%
dataset["disease"]
# Out:
# ['nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
#  'nf',
# ...

# %%
len(dataset)
# Out:
# 144962

# %%
set(dataset["disease"])
# Out:
# {'dcm', 'hcm', 'nf'}

# %%
dataset
# Out:
# Dataset({
#     features: ['input_ids', 'length', 'cell_type', 'individual', 'age', 'sex', 'disease', 'lvef'],
#     num_rows: 144962
# })

# %%
dataset['individual']
# Out:
# ['1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
#  '1622',
# ...

# %%
train_ids = ["1447", "1600", "1462", "1558", "1300", "1508", "1358", "1678", "1561", "1304", "1610", "1430", "1472", "1707", "1726", "1504", "1425", "1617", "1631", "1735", "1582", "1722", "1622", "1630", "1290", "1479", "1371", "1549", "1515"]

# %%
len(train_ids)
# Out:
# 29

# %%
len(set(dataset["individual"]))
# Out:
# 42

# %%
dataset
# Out:
# Dataset({
#     features: ['input_ids', 'length', 'cell_type', 'individual', 'age', 'sex', 'disease', 'lvef'],
#     num_rows: 144962
# })

# %%
set(dataset["cell_type"])
# Out:
# {'Cardiomyocyte1', 'Cardiomyocyte2', 'Cardiomyocyte3'}

# %%
set(dataset["disease"])
# Out:
# {'dcm', 'hcm', 'nf'}

# %%
dataset["state_key"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 dataset["state_key"]
#
# File c:\Users\xfang\anaconda3\envs\geneformer\lib\site-packages\datasets\arrow_dataset.py:2810, in Dataset.__getitem__(self, key)
#    2808 def __getitem__(self, key):  # noqa: F811
#    2809     """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2810     return self._getitem(key)
#
# File c:\Users\xfang\anaconda3\envs\geneformer\lib\site-packages\datasets\arrow_dataset.py:2794, in Dataset._getitem(self, key, **kwargs)
#    2792 format_kwargs = format_kwargs if format_kwargs is not None else {}
#    2793 formatter = get_formatter(format_type, features=self._info.features, **format_kwargs)
# -> 2794 pa_subtable = query_table(self._data, key, indices=self._indices)
#    2795 formatted_output = format_table(
# ...

# %%
len(set(dataset["individual"]))
# Out:
# 42

# %%
len(dataset)
# Out:
# 144962
